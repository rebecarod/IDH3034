# %%
print("""We are going to play a game of mad libs.
When you are asked a question, please answer with whatever word from that category that you like!""")
# Out:
# We are going to play a game of mad libs.
# When you are asked a question, please answer with whatever word from that category that you like!

# %%
print("Mad-lib 1:")
print("Adjective:")
adj1 = input("> ")
print("Noun:")
noun1 = input("> ")
print("Verb- Past-tense:")
verb1 = input("> ")
print("Adverb:")
adv1 = input("> ")
print("Adjective: ")
adj2 = input("> ")
print("Noun: ")
noun2 = input("> ")
print(f"""Your mad-lib:\nToday I went to the zoo. I saw a {adj1}
{noun1} jumping up and down in its tree. He {verb1} 
{adv1} through the large tunnel that led to its {adj2}
{noun2}. """)
# Out:
# Mad-lib 1:
# Adjective:
# > funny
# Noun:
# > nose
# Verb- Past-tense:
# > ran
# Adverb:
# > when
# Adjective:
# > smelly
# Noun:
# > oranges
# Today I went to the zoo. I saw a funny
# nose jumping up and down in its tree. He ran
# when through the large tunnel that led to its smelly
# oranges.

# %%
print("Mad-lib 2:")
print("Noun")
firstN = input("> ")
print("Adjective: ")
adj2 = input("> ")
print("Verb:")
verb1 = input("> ")
print("Adverb:")
adv1 = input("> ")
print("Verb- Past-Tense:")
verb2 = input("> ")
print("Adjective: ")
adj3 = input("> ")

print(f"""Your mad-lib:\nI got some peanuts and passed them
through the cage to a gigantic gray {firstN}
towering above my head. Feeding that animal made me
hungry. I went to get a {adj2} scoop of ice
cream. It filled my stomach. Afterwards I had to
{verb1} {adv1} to catch our bus. When
I got home I {verb2} my mom for a
{adj3} day at the zoo.""")
# Out:
# Mad-lib 2:
# Noun
# > apples
# Adjective:
# > hilarious
# Verb:
# > jogged
# Adverb:
# > after
# Verb- Past-Tense:
# > jogged
# Adjective:
# > foggy
# Your mad-lib:
# I got some peanuts and passed them
# through the cage to a gigantic gray apples
# towering above my head. Feeding that animal made me
# hungry. I went to get a hilarious scoop of ice
# cream. It filled my stomach. Afterwards I had to
# jogged after to catch our bus. When
# I got home I jogged my mom for a
# foggy day at the zoo.

# %%
print("Mad-lib 3:")
print("Plural Noun: ")
noun2 = input("> ")
print("Plural Noun: ")
noun3 = input("> ")
print("Verb:")
verb1 = input("> ")
print("Noun: ")
noun4 = input("> ")
print("ing Verb:")
verbing = input("> ")
print("Plural Noun: ")
nouning = input("> ")

print(f"""Your mad-lib:
When I go to the arcade with my {noun2} there are lots of games to play.
I spend lots of time there with my friends. In "Xmen" you can be different 
{noun3}. The point of the game is to {verb1}every robot. You also need to
save people, and then you can go to the next level. In "Star Wars" you 
are Luke Skywalker and you try to destroy every {noun4}. In a car 
racing / motorcycle racing game you need to beat every computerized vehicle that
you are {verbing} against. There are a whole lot of other cool games. 
When you play some games you win {nouning} for certain scores.""")
# Out:
# Mad-lib 3:
# Plural Noun:
# > oranges
# Plural Noun:
# > pears
# Verb:
# > run
# Noun:
# > apple
# ing Verb:
# > singing
# Plural Noun:
# > trees
# When I go to the arcade with my oranges
# there are lots of games to play. I spend lots of time there with
# my friends. In "Xmen" you can be different pears. The point of the game is to run
# every robot. You also need to save people, and then you can go to the
# next level. In "Star Wars" you are Luke Skywalker and you try to
# destroy every apple. In a car racing / motorcycle
# racing game you need to beat every computerized vehicle that
# you are singing against. There are a whole
# lot of other cool games. When you play some games you win
# trees for certain scores.

# %%
print("Mad-lib 4:")
print("Noun:")
noun1 = input("> ")
print("Plural Noun: ")
noun2 = input("> ")

print("Adjective:")
adj1 = input("> ")

print(f"""Your Mad-lib:
Once you're done you can cash in your tickets to get a big {noun1}. 
You can save your {noun2} for another time. When I
went to this arcade I didn't believe how much fun it would be.
You might annoy your parents by asking them over and over if
you can go back to there. So far I have had a lot of {adj1} every
time I've been to this great arcade! """)
# Out:
# Mad-lib 4:
# Noun:
# > apple
# Plural Noun:
# > pears
# Adjective:
# > pretty
# Your Mad-lib:
# Once you're done you can cash in your tickets to get a big apple.
# You can save your pears for another time. When I
# went to this arcade I didn't believe how much fun it would be.
# You might annoy your parents by asking them over and over if
# you can go back to there. So far I have had a lot of pretty every
# time I've been to this great arcade!

# %%
print("Mad-lib 5:")
print("Adjective:")
adj1 = input("> ")
print("Plural Noun:")
noun1 = input("> ")
print("Noun: ")
noun2 = input("> ")
print("Adverb:")
adv1 = input("> ")
print("Number:")
numb = input("> ")
print("Verb- Past-tense:")
verb1 = input("> ")


print(f"""My Day at the Fun Park From camp my fabulous group went to a
(an) {adj1} amusement park. It was a fun
park with lots of cool {noun1} and enjoyable
play structures. When we got there my annoying counselor
shouted loudly, \"Everybody off the {noun2}.\" We
all pushed out in a terrible hurry. My counselor handed out the
yellow tickets, and we scurried in. I was so excited, I couldn't
figure out what exciting thing to do first. I saw a scary roller
coaster I really liked so I {adv1} ran over to get
in the long line that had about {numb} people in
it. When I finally got on the roller coaster I was {verb1}.""")
# Out:
# Mad-lib 5:
# Adjective:
# > funny
# Plural Noun:
# > trees
# Noun:
# > apple
# Adverb:
# > before
# Number:
# > 50
# Verb- Past-tense:
# > ran
# My Day at the Fun Park From camp my fabulous group went to a
# (an) funny amusement park. It was a fun
# park with lots of cool trees and enjoyable
# play structures. When we got there my annoying counselor
# shouted loudly, "Everybody off the apple." We
# all pushed out in a terrible hurry. My counselor handed out the
# yellow tickets, and we scurried in. I was so excited, I couldn't
# figure out what exciting thing to do first. I saw a scary roller
# coaster I really liked so I before ran over to get
# in the long line that had about 50 people in
# it. When I finally got on the roller coaster I was ran.

# %%
print("Mad-lib 6:")
print("Adjective:")
adject = input("> ")
print("est Adjective:")
adj1 = input("> ")
print("Verb- Past-tense:")
verb1 = input("> ")
print("Adverb:")
adv1 = input("> ")
print("Adjective: ")
adj2 = input("> ")


print(f"""Your mad-lib:
My day was {adject}. In fact I was so nervous my two knees were
knocking together. This was the {adj1}
ride I had ever been on! In about two minutes "Crank" ! went the
grinding of the gears, and the ride began! When I got to the
bottom I was a little {verb1} but I was
proud of myself. The rest of the day went {adv1}. 
It was a {adj2} day at the fun park. """)
# Out:
# Mad-lib 6:
# Adjective:
# > funny
# est Adjective:
# > smelliest
# Verb- Past-tense:
# > ran
# Adverb:
# > when
# Adjective:
# > funny
# Your mad-lib:
# My day was funny. In fact I was so nervous my two knees were
# knocking together. This was the smelliest
# ride I had ever been on! In about two minutes "Crank" ! went the
# grinding of the gears, and the ride began! When I got to the
# bottom I was a little ran but I was
# proud of myself. The rest of the day went when.
# It was a funny) day at the fun park.

# %%
print("Mad-lib 7:")
print("Farm animal:")
farm = input("> ")
print("Verb- Past-tense:")
verb1 = input("> ")
print("Synonym for “big”:")
big = input("> ")
print("Object that has a circle shape:")
circ = input("> ")
print("Friends name:")
friend = input("> ")
print("any American president:")
prez = input("> ")

print(f"""I love Easter! One of the main reasons is the hunt that we
have for chocolate eggs!
This Easter though, the egg hunt was a little strange...
It was as strange as {farm}
{verb1} towards a {big} {circ}!
I was in the park with {friend}, and we
were hunting for eggs. We came across a tree that was
shaped like {prez}, and
decided to climb up it. """)
# Out:
# Mad-lib 7:
# Farm animal:
# > pig
# Verb- Past-tense:
# > ran
# Synonym for \“big\”:
# > huge
# Object that has a circle shape:
# > moon
# Friends name:
# > Jack
# any American president:
# > Obama
# I love Easter! One of the main reasons is the hunt that we
# have for chocolate eggs!
# This Easter though, the egg hunt was a little strange...
# It was as strange as pig
# ran towards a huge moon!
# I was in the park with Jack, and we
# were hunting for eggs. We came across a tree that was
# shaped like Obama, and
# decided to climb up it.

# %%
print("Mad-lib 8:")

print("Adjective:")
adj1 = input("> ")
print("Adjective:")
adj2 = input("> ")
print("Adjective:")
adj3 = input("> ")
print("Noun:")
noun1 = input("> ")
print("Adjective:")
adj4 = input("> ")
print("Adjective:")
adj5 = input("> ")

print("Noun: ")
noun2 = input("> ")
print("Verb:")
verb1 = input("> ")

print("Verb:")
verb2 = input("> ")
print("Adjective:")
adj6 = input("> ")
print("Noun: ")
noun3 = input("> ")
print("Verb:")
verb3 = input("> ")
print("Noun: ")
noun4 = input("> ")
print(f"""I walk through the color jungle. I take out my
{adj1} canteen. There's a
{adj2} parrot with a {adj3}
{noun1} in his mouth right in front of me in the
{adj4} trees! I gaze at his {adj5}
{noun2}. A sudden sound awakes me from my
daydream! A panther "s" {verb1} in front of my
head! I {verb2} his {adj6}
breath. I remember I have a packet of {noun3}
that makes go into a deep slumber! I {verb3} it
away in front of the {noun4}.""")
# Out:
# Mad-lib 8:
# Adjective:
# > funny
# Adjective:
# > rosy
# Adjective:
# > smelly
# Noun:
# > house
# Adjective:
# > beautiful
# Adjective:
# > foggy
# Noun:
# > trees
# Verb:
# > run
# Verb:
# > crawl
# Adjective:
# > funny
# Noun:
# > pear
# Verb:
# > jump
# Noun:
# > computer
# I walk through the color jungle. I take out my
# funny canteen. There's a
# rosy parrot with a smelly
# house in his mouth right in front of me in the
# beautiful trees! I gaze at his foggy
# trees. A sudden sound awakes me from my
# daydream! A panther "s" run in front of my
# head! I crawl his funny
# breath. I remember I have a packet of pear
# that makes go into a deep slumber! I jump it
# away in front of the computer.

# %%
print("Mad-lib 9:")

print("Name:")
name = input("> ")
print("Time:")
time = input("> ")
print("Meat product:")
meaty = input("> ")
print("Name:")
nothername = input("> ")
print("Animal:")
animal = input("> ")
print("Noun:")
stuff = input("> ")
print("-ing Verb:")
verb1 = input("> ")
print("Adjective:")
adj6 = input("> ")
print("Noun: ")
noun3 = input("> ")

print(f"""One beautiful summer morning {name} woke me up at {time}. It was just
near the end of the summer and I was trying to catch up on my
snoozing. {name} said “Wake up {meaty}! It’s the first day of school! Let’s get
going because my new teacher {nothername} is really a {animal}. I can’t wait to 
throw {stuff} at her. I hear she can’t resist {verb1} it with her teeth!”
I moaned and groaned for hours, but eventually, I woke and
starter getting dressed. I wore a {adj6} dress with a very long {noun3} attached to it.""")
# Out:
# Mad-lib 9:
# Name:
# > Dylan
# Time:
# > 3 o'clock
# Meat product:
# > ham
# Name:
# > Josh
# Animal:
# > dog
# Noun:
# > house
# -ing Verb:
# > running
# Adjective:
# > pretty
# Noun:
# > stairs
# One beautiful summer morning Dylan woke me up at 3 o'clock. It was just
# near the end of the summer and I was trying to catch up on my
# snoozing. Dylan said “Wake up ham! It’s the first day of school! Let’s get
# going because my new teacher Josh is really a dog. I can’t wait to
# throw house at her. I hear she can’t resist running it with her teeth!”
# I moaned and groaned for hours, but eventually, I woke and
# starter getting dressed. I wore a pretty dress with a very long stairs attached to it.

# %%
print("Mad-lib 10:")
print("Place:")
place = input("> ")
print("Adjective:")
adj6 = input("> ")
print("Adjective:")
adj7 = input("> ")
print("-ing Verb:")
verb1 = input("> ")
print("Animal:")
animal = input("> ")
print("Adjective:")
adv1 = input("> ")
print("Past tense Verb:")
pastv = input("> ")
print("Adjective:")
adv2 = input("> ")
print("Noun:")
stuff = input("> ")
print("Past tense Verb:")
pastw = input("> ")
print("Past tense Verb:")
pastl = input("> ")

print("Place:")
time = input("> ")

print("Verb:")
run = input("> ")

print(f"""Finally, we got {place} and it was very {adj6}.
There were {adj7} people {verb1} everywhere. There were also
people dressed up in {animal} costumes. I wish it had been 
more {adv1}, but we {pastv} anyway. We also went on some 
{adv2} rides, called "Magic {stuff}". Friend's name
nearly fell off a ride and had to be {pastw}. Later we 
went to the hotel and {pastl}. Next year, I want to go to 
{time}, where we can {run}.""")
# Out:
# Mad-lib 10:
# Place:
# > Disney
# Adjective:
# > beautiful
# Adjective:
# > weird
# -ing Verb:
# > sweating
# Animal:
# > lion
# Adjective:
# > sweaty
# Past tense Verb:
# > swam
# Adjective:
# > gross
# Noun:
# > house
# Past tense Verb:
# > looked
# Past tense Verb:
# > jumped
# Place:
# > Morocco
# Verb:
# > swim
# Name:
# > Rebeca
# Noun:
# > Joy
# Finally, we got Disney and it was very beautiful.
# There were weird people sweating everywhere. There were also
# people dressed up in lion costumes. I wish it had been
# more sweaty, but we swam anyway. We also went on some
# gross rides, called "Magic house". Friend's name
# nearly fell off a ride and had to be looked. Later we
# went to the hotel and jumped. Next year, I want to go to
# Morocco, where we can swim.
