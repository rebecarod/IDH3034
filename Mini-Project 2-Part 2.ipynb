# %%
import random
print("Mad lib generator:")

adjectives = ["chubby", "bald", "beautiful", "nice", "proud", "big", "mammoth", "witty", "stocky", "unkempt", "uptight"
             "medicated", "angry"]

nouns = ["gourmet", "pig", "gopher", "pillow", "stain", "graph", "acrobat", "graphite", "house", "pinhead", "actor"
        "adventurer", "grave", "stampede", "pizzeria", "greens", "ammonia", "plastic", "plate", "playpen", "pocket",
        "guava", "dingle berry", "weed whacker"]

names = ["Josh", "Rebeca", "Nathaniel", "Meghan", "Britney", "Veronica", "Melanie", "Dylan", "Camilo"]

verbs = ["trap", "sketch", "swat", "trip", "scatter", "fear", "cajole", "taunt", "mimic", "echo", "underestimate"]

adverbs = ["rudely", "physically", "ferociously", "excitedly", "politely", "arrogantly", "mortally", "majestically", 
          "soon", "knowingly"]

animals = ["dog", "cat", "cow", "pig", "bunny", "puppy", "aadvark"]
# Out:
# Mad lib generator:

# %%
print("Mad lib 1:\n")
print(f"""I walk through the color jungle. I take out my {random.choice(adjectives)} canteen. There's a
{random.choice(adjectives)} parrot with a {random.choice(adjectives)} {random.choice(nouns)} 
in his mouth right in front of me in the {random.choice(adjectives)} trees! 
I gaze at his {random.choice(adjectives)} {random.choice(nouns)}. A sudden sound awakes me from my
daydream! A panther "s" {random.choice(verbs)} in front of my head! I {random.choice(verbs)} his {random.choice(adjectives)} breath. 
I remember I have a packet of {random.choice(nouns)} that makes go into a deep slumber! I {random.choice(verbs)} it
away in front of the {random.choice(nouns)}.""")

print("\nMad lib 2: \n")
print(f"""I love Easter! One of the main reasons is the hunt that we
have for chocolate eggs! This Easter though, the egg hunt was a little strange...
It was as strange as {random.choice(animals)} {random.choice(verbs)} towards a {random.choice(adjectives)} circle!
I was in the park with {random.choice(names)}, and we were hunting for eggs. We came 
across a tree that was shaped like {random.choice(names)}, and
decided to climb up it. """)

print("Mad lib 3:\n")
print(f"""Your mad-lib:
My day was {random.choice(adjectives)}. In fact I was so nervous my two knees were
knocking together. This was the {random.choice(adjectives)}
ride I had ever been on! In about two minutes "Crank" ! went the
grinding of the gears, and the ride began! When I got to the
bottom I was a little {random.choice(verbs)} but I was
proud of myself. The rest of the day went {random.choice(adverbs)}. 
It was a {random.choice(adjectives)} day at the fun park. """)

print("\nMad lib 4:\n")
print(f"""My Day at the Fun Park From camp my fabulous group went to a
(an) {random.choice(adjectives)} amusement park. It was a fun
park with lots of cool {random.choice(nouns)} and enjoyable
play structures. When we got there my annoying counselor
shouted loudly, \"Everybody off the {random.choice(nouns)}.\" We
all pushed out in a terrible hurry. My counselor handed out the
yellow tickets, and we scurried in. I was so excited, I couldn't
figure out what exciting thing to do first. I saw a scary roller
coaster I really liked so I {random.choice(adverbs)} ran over to get
in the long line that had about {random.randint(1,100000)} people in
it. When I finally got on the roller coaster I was {random.choice(verbs)}.""")

print("\nMad lib 5:\n")
print(f"""Once you're done you can cash in your tickets to get a big {random.choice(nouns)}. 
You can save your {random.choice(nouns)} for another time. When I
went to this arcade I didn't believe how much fun it would be.
You might annoy your parents by asking them over and over if
you can go back to there. So far I have had a lot of {random.choice(adjectives)} every
time I've been to this great arcade! """)

print("\nMad lib 6:\n")
print(f"""When I go to the arcade with my {random.choice(nouns)} there are lots of games to play.
I spend lots of time there with my friends. In "Xmen" you can be different 
{random.choice(nouns)}. The point of the game is to {random.choice(verbs)} every robot. You also need to
save people, and then you can go to the next level. In "Star Wars" you 
are Luke Skywalker and you try to destroy every {random.choice(nouns)}. In a car 
racing / motorcycle racing game you need to beat every computerized vehicle that
you are {random.choice(verbs)} against. There are a whole lot of other cool games. 
When you play some games you win {random.choice(nouns)} for certain scores.""")

print("\nMad lib 7:\n")
print(f"""Your mad-lib:\nI got some peanuts and passed them
through the cage to a gigantic gray {random.choice(nouns)}
towering above my head. Feeding that animal made me
hungry. I went to get a {random.choice(adjectives)} scoop of ice
cream. It filled my stomach. Afterwards I had to
{random.choice(verbs)} {random.choice(adjectives)} to catch our bus. When
I got home I {random.choice(verbs)} my mom for a
{random.choice(adjectives)} day at the zoo.""")

print("\nMad lib 8:\n")
print(f"""Finally, we got {random.choice(nouns)} and it was very {random.choice(adjectives)}.
There were {random.choice(adjectives)} people {random.choice(verbs)} everywhere. There were also
people dressed up in {random.choice(animals)} costumes. I wish it had been 
more {random.choice(adverbs)}, but we {random.choice(verbs)} anyway. We also went on some 
{random.choice(adjectives)} rides, called "Magic {random.choice(nouns)}". Friend's name
nearly fell off a ride and had to be {random.choice(verbs)}. Later we 
went to the hotel and {random.choice(verbs)}. Next year, I want to go to 
in the morning, where we can {random.choice(verbs)}.""")

print("\nMad lib 9: \n")
print(f"""One beautiful summer morning {random.choice(names)} woke me up at 9:00. It was just
near the end of the summer and I was trying to catch up on my
snoozing. {random.choice(names)} said “Wake up {random.choice(names)}! It’s the first day of school! Let’s get
going because my new teacher {random.choice(names)} is really a {random.choice(animals)}. I can’t wait to 
throw {random.choice(nouns)} at her. I hear she can’t resist {random.choice(verbs)} it with her teeth!”
I moaned and groaned for hours, but eventually, I woke and
starter getting dressed. I wore a {random.choice(adjectives)} dress with a very long {random.choice(nouns)} attached to it.""")
# Out:
# Mad lib 1:
#
# I walk through the color jungle. I take out my bald canteen. There's a
# big parrot with a beautiful gourmet
# in his mouth right in front of me in the witty trees!
# I gaze at his bald acrobat. A sudden sound awakes me from my
# daydream! A panther "s" taunt in front of my head! I cajole his angry breath.
# I remember I have a packet of graphite that makes go into a deep slumber! I swat it
# away in front of the pig.
#
# Mad lib 2:
#
# I love Easter! One of the main reasons is the hunt that we
# have for chocolate eggs! This Easter though, the egg hunt was a little strange...
# It was as strange as pig scatter towards a chubby circle!
# I was in the park with Meghan, and we were hunting for eggs. We came
# across a tree that was shaped like Rebeca, and
# decided to climb up it.
# Mad lib 3:
#
# Your mad-lib:
# My day was beautiful. In fact I was so nervous my two knees were
# knocking together. This was the stocky
# ...
